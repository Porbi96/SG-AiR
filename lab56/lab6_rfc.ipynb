# %%
# import bibliotek
import os
import librosa
import pickle
import sklearn
import numpy

# %%
# 2. Wybór danych treningowych i testowych

# Zautomatyzowany i losowy sposób to użycie:
# "from sklearn.model_selection import train_test_split" oraz funkcji "train_test_split()"

best_mfcc = 0
best_quality = 0
for N in range(1,101):
    # wczytanie danych
    database = open(f'classes/database{N}.pkl', 'rb')
    classes, samples, labels = pickle.load(database)
    database.close()

    # wybierzmy 10 pierwszych próbek z każdej klasy jako uczące
    # oraz kolejne 2 z każdej klasy jako testowe
    # uwaga! train_size + test_size NIE może przekroczyć class_size (poprzedni punkt)
    train_size = 40
    test_size = 10
    train_samples = []
    train_labels = []
    test_samples = []
    test_labels = []
    for classname in classes:
        train_size_index = 0
        test_size_index = 0
        for i in range(len(labels)):
            if labels[i] == classname and train_size_index < train_size:
                train_samples.append(samples[i])
                train_labels.append(labels[i])
                train_size_index += 1
            elif labels[i] == classname and test_size_index < test_size:
                test_samples.append(samples[i])
                test_labels.append(labels[i])
                test_size_index += 1
            if train_size_index == train_size and test_size_index == test_size:
                break

    # proszę sprawdzić, czy dane zostały wybrane prawidłowo


    # 3. Uczenie klasyfikatora danymi treningowymi

    # Lista klasyfikatorów: https://stackabuse.com/overview-of-classification-methods-in-python-with-scikit-learn/
    # Prosty tutorial: https://www.digitalocean.com/community/tutorials/how-to-build-a-machine-learning-classifier-in-python-with-scikit-learn

    # skalowanie/normalizacja danych
    from sklearn.preprocessing import StandardScaler
    scaler = StandardScaler()
    scaler.fit(train_samples)
    train_samples = scaler.transform(train_samples)
    test_samples = scaler.transform(test_samples)

    # uczenie
    from sklearn.ensemble import RandomForestClassifier
    n = 100
    classifier = RandomForestClassifier(n_estimators = n)
    classifier.fit(train_samples, train_labels)


    # 4. Klasyfikacja nieznanych próbek
    predicted_labels = classifier.predict(test_samples)

    # zobaczmy wynik - zakomentować dla dużych zbiorów
    # print(test_labels)
    # print(predicted_labels)


    # 5. Ocena klasyfikatora
    # print(test_labels == predicted_labels)
    quality = numpy.sum(test_labels == predicted_labels) / len(test_labels) * 100;
    print(f'mfcc={N} Ocena klasyfikatora: %.2f %%' % quality)
    if (quality > best_quality):
        best_mfcc = N
        best_quality = quality

print(f"best_mfcc = {best_mfcc}; best_quality = {best_quality}")
n_mfcc_optimal = best_mfcc
# Out:
# mfcc=1 Ocena klasyfikatora: 3.00 %
# mfcc=2 Ocena klasyfikatora: 5.33 %
# mfcc=3 Ocena klasyfikatora: 5.33 %
# mfcc=4 Ocena klasyfikatora: 6.00 %
# mfcc=5 Ocena klasyfikatora: 7.67 %
# mfcc=6 Ocena klasyfikatora: 9.00 %
# mfcc=7 Ocena klasyfikatora: 9.33 %
# mfcc=8 Ocena klasyfikatora: 12.00 %
# mfcc=9 Ocena klasyfikatora: 12.67 %
# mfcc=10 Ocena klasyfikatora: 13.00 %
# mfcc=11 Ocena klasyfikatora: 11.33 %
# mfcc=12 Ocena klasyfikatora: 11.33 %
# mfcc=13 Ocena klasyfikatora: 11.67 %
# mfcc=14 Ocena klasyfikatora: 12.00 %
# mfcc=15 Ocena klasyfikatora: 14.33 %
# mfcc=16 Ocena klasyfikatora: 12.33 %
# mfcc=17 Ocena klasyfikatora: 13.00 %
# mfcc=18 Ocena klasyfikatora: 13.67 %
# mfcc=19 Ocena klasyfikatora: 12.33 %
# mfcc=20 Ocena klasyfikatora: 14.00 %
# mfcc=21 Ocena klasyfikatora: 13.67 %
# mfcc=22 Ocena klasyfikatora: 15.33 %
# mfcc=23 Ocena klasyfikatora: 13.67 %
# mfcc=24 Ocena klasyfikatora: 12.33 %
# mfcc=25 Ocena klasyfikatora: 14.33 %
# mfcc=26 Ocena klasyfikatora: 15.00 %
# mfcc=27 Ocena klasyfikatora: 12.67 %
# mfcc=28 Ocena klasyfikatora: 15.33 %
# mfcc=29 Ocena klasyfikatora: 14.33 %
# mfcc=30 Ocena klasyfikatora: 14.33 %
# mfcc=31 Ocena klasyfikatora: 14.67 %
# mfcc=32 Ocena klasyfikatora: 11.67 %
# mfcc=33 Ocena klasyfikatora: 12.67 %
# mfcc=34 Ocena klasyfikatora: 11.67 %
# mfcc=35 Ocena klasyfikatora: 13.67 %
# mfcc=36 Ocena klasyfikatora: 15.67 %
# mfcc=37 Ocena klasyfikatora: 12.33 %
# mfcc=38 Ocena klasyfikatora: 10.67 %
# mfcc=39 Ocena klasyfikatora: 13.33 %
# mfcc=40 Ocena klasyfikatora: 13.00 %
# mfcc=41 Ocena klasyfikatora: 12.33 %
# mfcc=42 Ocena klasyfikatora: 16.67 %
# mfcc=43 Ocena klasyfikatora: 13.00 %
# mfcc=44 Ocena klasyfikatora: 12.67 %
# mfcc=45 Ocena klasyfikatora: 12.00 %
# mfcc=46 Ocena klasyfikatora: 14.33 %
# mfcc=47 Ocena klasyfikatora: 13.00 %
# mfcc=48 Ocena klasyfikatora: 11.67 %
# mfcc=49 Ocena klasyfikatora: 11.33 %
# mfcc=50 Ocena klasyfikatora: 13.00 %
# mfcc=51 Ocena klasyfikatora: 12.67 %
# mfcc=52 Ocena klasyfikatora: 11.00 %
# mfcc=53 Ocena klasyfikatora: 12.67 %
# mfcc=54 Ocena klasyfikatora: 15.33 %
# mfcc=55 Ocena klasyfikatora: 11.67 %
# mfcc=56 Ocena klasyfikatora: 14.33 %
# mfcc=57 Ocena klasyfikatora: 11.00 %
# mfcc=58 Ocena klasyfikatora: 16.00 %
# mfcc=59 Ocena klasyfikatora: 12.33 %
# mfcc=60 Ocena klasyfikatora: 11.33 %
# mfcc=61 Ocena klasyfikatora: 13.00 %
# mfcc=62 Ocena klasyfikatora: 13.00 %
# mfcc=63 Ocena klasyfikatora: 11.33 %
# mfcc=64 Ocena klasyfikatora: 11.67 %
# mfcc=65 Ocena klasyfikatora: 13.33 %
# mfcc=66 Ocena klasyfikatora: 13.33 %
# mfcc=67 Ocena klasyfikatora: 12.00 %
# mfcc=68 Ocena klasyfikatora: 12.00 %
# mfcc=69 Ocena klasyfikatora: 13.67 %
# mfcc=70 Ocena klasyfikatora: 13.33 %
# mfcc=71 Ocena klasyfikatora: 13.67 %
# mfcc=72 Ocena klasyfikatora: 12.67 %
# mfcc=73 Ocena klasyfikatora: 10.67 %
# mfcc=74 Ocena klasyfikatora: 11.33 %
# mfcc=75 Ocena klasyfikatora: 13.33 %
# mfcc=76 Ocena klasyfikatora: 9.67 %
# mfcc=77 Ocena klasyfikatora: 11.33 %
# mfcc=78 Ocena klasyfikatora: 10.33 %
# mfcc=79 Ocena klasyfikatora: 13.00 %
# mfcc=80 Ocena klasyfikatora: 11.00 %
# mfcc=81 Ocena klasyfikatora: 11.00 %
# mfcc=82 Ocena klasyfikatora: 13.33 %
# mfcc=83 Ocena klasyfikatora: 12.00 %
# mfcc=84 Ocena klasyfikatora: 11.33 %
# mfcc=85 Ocena klasyfikatora: 11.33 %
# mfcc=86 Ocena klasyfikatora: 10.67 %
# mfcc=87 Ocena klasyfikatora: 12.33 %
# mfcc=88 Ocena klasyfikatora: 11.67 %
# mfcc=89 Ocena klasyfikatora: 11.33 %
# mfcc=90 Ocena klasyfikatora: 12.00 %
# mfcc=91 Ocena klasyfikatora: 10.00 %
# mfcc=92 Ocena klasyfikatora: 11.67 %
# mfcc=93 Ocena klasyfikatora: 12.67 %
# mfcc=94 Ocena klasyfikatora: 11.00 %
# mfcc=95 Ocena klasyfikatora: 12.67 %
# mfcc=96 Ocena klasyfikatora: 11.00 %
# mfcc=97 Ocena klasyfikatora: 12.67 %
# mfcc=98 Ocena klasyfikatora: 13.33 %
# mfcc=99 Ocena klasyfikatora: 10.33 %
# mfcc=100 Ocena klasyfikatora: 11.00 %
# best_mfcc = 42; best_quality = 16.666666666666664

# %%
# 2. Dobór optymalny zbioru testowego

# Zautomatyzowany i losowy sposób to użycie:
# "from sklearn.model_selection import train_test_split" oraz funkcji "train_test_split()"

best_mfcc = n_mfcc_optimal
print(f"best_mfcc: {best_mfcc}")

best_train_size = 0
best_quality = 0
for N in range(1,91):
    # wczytanie danych
    database = open(f'classes/database{best_mfcc}.pkl', 'rb')
    classes, samples, labels = pickle.load(database)
    database.close()

    # wybierzmy 10 pierwszych próbek z każdej klasy jako uczące
    # oraz kolejne 2 z każdej klasy jako testowe
    # uwaga! train_size + test_size NIE może przekroczyć class_size (poprzedni punkt)
    train_size = N
    test_size = 10
    train_samples = []
    train_labels = []
    test_samples = []
    test_labels = []
    for classname in classes:
        train_size_index = 0
        test_size_index = 0
        for i in range(len(labels)):
            if labels[i] == classname and train_size_index < train_size:
                train_samples.append(samples[i])
                train_labels.append(labels[i])
                train_size_index += 1
            elif labels[i] == classname and test_size_index < test_size:
                test_samples.append(samples[i])
                test_labels.append(labels[i])
                test_size_index += 1
            if train_size_index == train_size and test_size_index == test_size:
                break

    # proszę sprawdzić, czy dane zostały wybrane prawidłowo


    # 3. Uczenie klasyfikatora danymi treningowymi

    # Lista klasyfikatorów: https://stackabuse.com/overview-of-classification-methods-in-python-with-scikit-learn/
    # Prosty tutorial: https://www.digitalocean.com/community/tutorials/how-to-build-a-machine-learning-classifier-in-python-with-scikit-learn

    # skalowanie/normalizacja danych
    from sklearn.preprocessing import StandardScaler
    scaler = StandardScaler()
    scaler.fit(train_samples)
    train_samples = scaler.transform(train_samples)
    test_samples = scaler.transform(test_samples)

    # uczenie
    from sklearn.ensemble import RandomForestClassifier
    n = 100
    classifier = RandomForestClassifier(n_estimators = n)
    classifier.fit(train_samples, train_labels)
    
    # 4. Klasyfikacja nieznanych próbek
    predicted_labels = classifier.predict(test_samples)

    # zobaczmy wynik - zakomentować dla dużych zbiorów
    # print(test_labels)
    # print(predicted_labels)


    # 5. Ocena klasyfikatora
    # print(test_labels == predicted_labels)
    quality = numpy.sum(test_labels == predicted_labels) / len(test_labels) * 100;
    print(f'train_size={N} Ocena klasyfikatora: %.2f %%' % quality)
    if (quality > best_quality):
        best_train_size = N
        best_quality = quality

print(f"best_train_size = {best_train_size}; best_quality = {best_quality}")
train_size_optimal = best_train_size
# Out:
# best_mfcc: 42
# train_size=1 Ocena klasyfikatora: 4.92 %
# train_size=2 Ocena klasyfikatora: 6.91 %
# train_size=3 Ocena klasyfikatora: 8.91 %
# train_size=4 Ocena klasyfikatora: 8.94 %
# train_size=5 Ocena klasyfikatora: 8.97 %
# train_size=6 Ocena klasyfikatora: 10.67 %
# train_size=7 Ocena klasyfikatora: 10.33 %
# train_size=8 Ocena klasyfikatora: 9.00 %
# train_size=9 Ocena klasyfikatora: 11.00 %
# train_size=10 Ocena klasyfikatora: 14.67 %
# train_size=11 Ocena klasyfikatora: 17.67 %
# train_size=12 Ocena klasyfikatora: 17.00 %
# train_size=13 Ocena klasyfikatora: 14.67 %
# train_size=14 Ocena klasyfikatora: 14.33 %
# train_size=15 Ocena klasyfikatora: 12.67 %
# train_size=16 Ocena klasyfikatora: 14.00 %
# train_size=17 Ocena klasyfikatora: 10.33 %
# train_size=18 Ocena klasyfikatora: 10.00 %
# train_size=19 Ocena klasyfikatora: 9.33 %
# train_size=20 Ocena klasyfikatora: 11.33 %
# train_size=21 Ocena klasyfikatora: 11.67 %
# train_size=22 Ocena klasyfikatora: 15.33 %
# train_size=23 Ocena klasyfikatora: 15.67 %
# train_size=24 Ocena klasyfikatora: 16.00 %
# train_size=25 Ocena klasyfikatora: 13.67 %
# train_size=26 Ocena klasyfikatora: 13.33 %
# train_size=27 Ocena klasyfikatora: 13.33 %
# train_size=28 Ocena klasyfikatora: 13.33 %
# train_size=29 Ocena klasyfikatora: 10.00 %
# train_size=30 Ocena klasyfikatora: 11.33 %
# train_size=31 Ocena klasyfikatora: 10.33 %
# train_size=32 Ocena klasyfikatora: 14.00 %
# train_size=33 Ocena klasyfikatora: 11.67 %
# train_size=34 Ocena klasyfikatora: 13.33 %
# train_size=35 Ocena klasyfikatora: 13.00 %
# train_size=36 Ocena klasyfikatora: 12.67 %
# train_size=37 Ocena klasyfikatora: 11.33 %
# train_size=38 Ocena klasyfikatora: 13.67 %
# train_size=39 Ocena klasyfikatora: 12.67 %
# train_size=40 Ocena klasyfikatora: 13.67 %
# train_size=41 Ocena klasyfikatora: 11.67 %
# train_size=42 Ocena klasyfikatora: 12.33 %
# train_size=43 Ocena klasyfikatora: 12.33 %
# train_size=44 Ocena klasyfikatora: 12.00 %
# train_size=45 Ocena klasyfikatora: 12.33 %
# train_size=46 Ocena klasyfikatora: 14.00 %
# train_size=47 Ocena klasyfikatora: 10.00 %
# train_size=48 Ocena klasyfikatora: 13.67 %
# train_size=49 Ocena klasyfikatora: 11.00 %
# train_size=50 Ocena klasyfikatora: 15.00 %
# train_size=51 Ocena klasyfikatora: 12.33 %
# train_size=52 Ocena klasyfikatora: 11.67 %
# train_size=53 Ocena klasyfikatora: 11.33 %
# train_size=54 Ocena klasyfikatora: 13.00 %
# train_size=55 Ocena klasyfikatora: 16.00 %
# train_size=56 Ocena klasyfikatora: 15.67 %
# train_size=57 Ocena klasyfikatora: 17.00 %
# train_size=58 Ocena klasyfikatora: 17.67 %
# train_size=59 Ocena klasyfikatora: 16.67 %
# train_size=60 Ocena klasyfikatora: 13.67 %
# train_size=61 Ocena klasyfikatora: 13.67 %
# train_size=62 Ocena klasyfikatora: 13.67 %
# train_size=63 Ocena klasyfikatora: 18.33 %
# train_size=64 Ocena klasyfikatora: 14.00 %
# train_size=65 Ocena klasyfikatora: 14.33 %
# train_size=66 Ocena klasyfikatora: 16.67 %
# train_size=67 Ocena klasyfikatora: 17.67 %
# train_size=68 Ocena klasyfikatora: 16.67 %
# train_size=69 Ocena klasyfikatora: 18.00 %
# train_size=70 Ocena klasyfikatora: 19.33 %
# train_size=71 Ocena klasyfikatora: 17.00 %
# train_size=72 Ocena klasyfikatora: 15.33 %
# train_size=73 Ocena klasyfikatora: 15.67 %
# train_size=74 Ocena klasyfikatora: 13.33 %
# train_size=75 Ocena klasyfikatora: 12.67 %
# train_size=76 Ocena klasyfikatora: 18.67 %
# train_size=77 Ocena klasyfikatora: 20.33 %
# train_size=78 Ocena klasyfikatora: 22.33 %
# train_size=79 Ocena klasyfikatora: 15.67 %
# train_size=80 Ocena klasyfikatora: 17.33 %
# train_size=81 Ocena klasyfikatora: 18.33 %
# train_size=82 Ocena klasyfikatora: 15.33 %
# train_size=83 Ocena klasyfikatora: 17.67 %
# train_size=84 Ocena klasyfikatora: 17.00 %
# train_size=85 Ocena klasyfikatora: 16.67 %
# train_size=86 Ocena klasyfikatora: 14.00 %
# train_size=87 Ocena klasyfikatora: 14.00 %
# train_size=88 Ocena klasyfikatora: 14.67 %
# train_size=89 Ocena klasyfikatora: 15.33 %
# train_size=90 Ocena klasyfikatora: 13.67 %
# best_train_size = 78; best_quality = 22.333333333333332

# %%
# 2. Dobór optymalny parametru n

# Zautomatyzowany i losowy sposób to użycie:
# "from sklearn.model_selection import train_test_split" oraz funkcji "train_test_split()"

best_mfcc = n_mfcc_optimal
best_train_size = train_size_optimal

best_n = 0
best_quality = 0
for N in range(10,101):
    # wczytanie danych
    database = open(f'classes/database{best_mfcc}.pkl', 'rb')
    classes, samples, labels = pickle.load(database)
    database.close()

    # wybierzmy 10 pierwszych próbek z każdej klasy jako uczące
    # oraz kolejne 2 z każdej klasy jako testowe
    # uwaga! train_size + test_size NIE może przekroczyć class_size (poprzedni punkt)
    train_size = best_train_size
    test_size = 10
    train_samples = []
    train_labels = []
    test_samples = []
    test_labels = []
    for classname in classes:
        train_size_index = 0
        test_size_index = 0
        for i in range(len(labels)):
            if labels[i] == classname and train_size_index < train_size:
                train_samples.append(samples[i])
                train_labels.append(labels[i])
                train_size_index += 1
            elif labels[i] == classname and test_size_index < test_size:
                test_samples.append(samples[i])
                test_labels.append(labels[i])
                test_size_index += 1
            if train_size_index == train_size and test_size_index == test_size:
                break

    # proszę sprawdzić, czy dane zostały wybrane prawidłowo


    # 3. Uczenie klasyfikatora danymi treningowymi

    # Lista klasyfikatorów: https://stackabuse.com/overview-of-classification-methods-in-python-with-scikit-learn/
    # Prosty tutorial: https://www.digitalocean.com/community/tutorials/how-to-build-a-machine-learning-classifier-in-python-with-scikit-learn

    # skalowanie/normalizacja danych
    from sklearn.preprocessing import StandardScaler
    scaler = StandardScaler()
    scaler.fit(train_samples)
    train_samples = scaler.transform(train_samples)
    test_samples = scaler.transform(test_samples)

    # uczenie
    from sklearn.ensemble import RandomForestClassifier
    n = N
    classifier = RandomForestClassifier(n_estimators = n)
    classifier.fit(train_samples, train_labels)


    # 4. Klasyfikacja nieznanych próbek
    predicted_labels = classifier.predict(test_samples)

    # zobaczmy wynik - zakomentować dla dużych zbiorów
    # print(test_labels)
    # print(predicted_labels)


    # 5. Ocena klasyfikatora
    # print(test_labels == predicted_labels)
    quality = numpy.sum(test_labels == predicted_labels) / len(test_labels) * 100;
    print(f'N={N} Ocena klasyfikatora: %.2f %%' % quality)
    if (quality > best_quality):
        best_n = N
        best_quality = quality

print(f"best_n = {best_n}; best_quality = {best_quality}")
n_optimal = best_n
# Out:
# N=10 Ocena klasyfikatora: 7.67 %
# N=11 Ocena klasyfikatora: 13.00 %
# N=12 Ocena klasyfikatora: 14.33 %
# N=13 Ocena klasyfikatora: 10.33 %
# N=14 Ocena klasyfikatora: 13.33 %
# N=15 Ocena klasyfikatora: 14.67 %
# N=16 Ocena klasyfikatora: 10.67 %
# N=17 Ocena klasyfikatora: 14.67 %
# N=18 Ocena klasyfikatora: 13.67 %
# N=19 Ocena klasyfikatora: 13.67 %
# N=20 Ocena klasyfikatora: 15.00 %
# N=21 Ocena klasyfikatora: 15.67 %
# N=22 Ocena klasyfikatora: 13.67 %
# N=23 Ocena klasyfikatora: 15.67 %
# N=24 Ocena klasyfikatora: 15.33 %
# N=25 Ocena klasyfikatora: 13.67 %
# N=26 Ocena klasyfikatora: 16.00 %
# N=27 Ocena klasyfikatora: 16.00 %
# N=28 Ocena klasyfikatora: 17.00 %
# N=29 Ocena klasyfikatora: 15.67 %
# N=30 Ocena klasyfikatora: 15.67 %
# N=31 Ocena klasyfikatora: 17.00 %
# N=32 Ocena klasyfikatora: 17.00 %
# N=33 Ocena klasyfikatora: 17.00 %
# N=34 Ocena klasyfikatora: 15.67 %
# N=35 Ocena klasyfikatora: 14.67 %
# N=36 Ocena klasyfikatora: 18.33 %
# N=37 Ocena klasyfikatora: 16.67 %
# N=38 Ocena klasyfikatora: 16.67 %
# N=39 Ocena klasyfikatora: 18.33 %
# N=40 Ocena klasyfikatora: 15.67 %
# N=41 Ocena klasyfikatora: 18.00 %
# N=42 Ocena klasyfikatora: 18.67 %
# N=43 Ocena klasyfikatora: 18.33 %
# N=44 Ocena klasyfikatora: 16.67 %
# N=45 Ocena klasyfikatora: 18.00 %
# N=46 Ocena klasyfikatora: 15.33 %
# N=47 Ocena klasyfikatora: 17.00 %
# N=48 Ocena klasyfikatora: 18.67 %
# N=49 Ocena klasyfikatora: 20.33 %
# N=50 Ocena klasyfikatora: 18.33 %
# N=51 Ocena klasyfikatora: 18.00 %
# N=52 Ocena klasyfikatora: 16.67 %
# N=53 Ocena klasyfikatora: 19.67 %
# N=54 Ocena klasyfikatora: 17.33 %
# N=55 Ocena klasyfikatora: 18.67 %
# N=56 Ocena klasyfikatora: 17.33 %
# N=57 Ocena klasyfikatora: 18.33 %
# N=58 Ocena klasyfikatora: 17.33 %
# N=59 Ocena klasyfikatora: 18.67 %
# N=60 Ocena klasyfikatora: 17.33 %
# N=61 Ocena klasyfikatora: 19.67 %
# N=62 Ocena klasyfikatora: 21.33 %
# N=63 Ocena klasyfikatora: 20.00 %
# N=64 Ocena klasyfikatora: 18.67 %
# N=65 Ocena klasyfikatora: 21.33 %
# N=66 Ocena klasyfikatora: 19.00 %
# N=67 Ocena klasyfikatora: 18.67 %
# N=68 Ocena klasyfikatora: 18.67 %
# N=69 Ocena klasyfikatora: 16.67 %
# N=70 Ocena klasyfikatora: 19.00 %
# N=71 Ocena klasyfikatora: 19.33 %
# N=72 Ocena klasyfikatora: 19.00 %
# N=73 Ocena klasyfikatora: 20.00 %
# N=74 Ocena klasyfikatora: 19.00 %
# N=75 Ocena klasyfikatora: 20.33 %
# N=76 Ocena klasyfikatora: 19.33 %
# N=77 Ocena klasyfikatora: 21.00 %
# N=78 Ocena klasyfikatora: 17.67 %
# N=79 Ocena klasyfikatora: 19.00 %
# N=80 Ocena klasyfikatora: 20.67 %
# N=81 Ocena klasyfikatora: 16.67 %
# N=82 Ocena klasyfikatora: 18.00 %
# N=83 Ocena klasyfikatora: 22.33 %
# N=84 Ocena klasyfikatora: 18.00 %
# N=85 Ocena klasyfikatora: 20.67 %
# N=86 Ocena klasyfikatora: 19.67 %
# N=87 Ocena klasyfikatora: 19.33 %
# N=88 Ocena klasyfikatora: 16.00 %
# N=89 Ocena klasyfikatora: 17.00 %
# N=90 Ocena klasyfikatora: 18.33 %
# N=91 Ocena klasyfikatora: 18.00 %
# N=92 Ocena klasyfikatora: 18.33 %
# N=93 Ocena klasyfikatora: 19.67 %
# N=94 Ocena klasyfikatora: 18.33 %
# N=95 Ocena klasyfikatora: 18.67 %
# N=96 Ocena klasyfikatora: 19.00 %
# N=97 Ocena klasyfikatora: 18.00 %
# N=98 Ocena klasyfikatora: 20.67 %
# N=99 Ocena klasyfikatora: 22.67 %
# N=100 Ocena klasyfikatora: 21.33 %
# best_n = 99; best_quality = 22.666666666666664

# %%
# Dobrane parametry:
# mfcc = 42
# train size = 78
# n_estimators = 99

# Finalna wartosc parametru quality: 22,7
